# %%
#import the packages
import pandas as pd
import numpy as np
import nltk as nlp

# %%
#load the csv file
df = pd.read_csv("ExtractedTweets.csv")
#drop the missing values row wise
df.dropna(axis = 0, inplace = True)
df.head()
# Out:
#       Party         Handle                                              Tweet
# 0  Democrat  RepDarrenSoto  Today, Senate Dems vote to #SaveTheInternet. P...
# 1  Democrat  RepDarrenSoto  RT @WinterHavenSun: Winter Haven resident / Al...
# 2  Democrat  RepDarrenSoto  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3  Democrat  RepDarrenSoto  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4  Democrat  RepDarrenSoto  RT @Vegalteno: Hurricane season starts on June...

# %%
# Data Types
df.dtypes
# Out:
# Party     object
# Handle    object
# Tweet     object
# dtype: object

# %%
#assigning Decomart label and Republican label with 1 and 0 respectively
df["Party_log"] = [1 if each == "Democrat" else 0 for each in df.Party]
print(df.shape)
df
# Out:
# (86460, 4)
#             Party         Handle  \
# 0        Democrat  RepDarrenSoto
# 1        Democrat  RepDarrenSoto
# 2        Democrat  RepDarrenSoto
# 3        Democrat  RepDarrenSoto
# 4        Democrat  RepDarrenSoto
# ...           ...            ...
# 86455  Republican    RepTomPrice
# 86456  Republican    RepTomPrice
# 86457  Republican    RepTomPrice
# 86458  Republican    RepTomPrice
# 86459  Republican    RepTomPrice
#
#                                                    Tweet  Party_log
# 0      Today, Senate Dems vote to #SaveTheInternet. P...          1
# 1      RT @WinterHavenSun: Winter Haven resident / Al...          1
# 2      RT @NBCLatino: .@RepDarrenSoto noted that Hurr...          1
# 3      RT @NALCABPolicy: Meeting with @RepDarrenSoto ...          1
# 4      RT @Vegalteno: Hurricane season starts on June...          1
# ...                                                  ...        ...
# 86455  Check out my op-ed on need for End Executive O...          0
# 86456  Yesterday, Betty &amp; I had a great time lear...          0
# 86457  We are forever grateful for the service and sa...          0
# 86458  Happy first day of school @CobbSchools! #CobbB...          0
# 86459  #Zika fears realized in Florida. House GOP act...          0
#
# [86460 rows x 4 columns]

# %%
#First tweet, trying to understand the tweets in the dataset
df.Tweet[0]
# Out:
# 'Today, Senate Dems vote to #SaveTheInternet. Proud to support similar #NetNeutrality legislation here in the House… https://t.co/n3tggDLU1L'

# %%
df.Tweet[1]
# Out:
# 'RT @WinterHavenSun: Winter Haven resident / Alta Vista teacher is one of several recognized by @RepDarrenSoto for National Teacher Apprecia…'

# %%
df.Tweet[86459]
# Out:
# '#Zika fears realized in Florida. House GOP acted to prevent crisis. Dems inaction, inexcusable! Time to put politics aside &amp; work together!'

# %%
#Count for each label
df.Party.value_counts()
# Out:
# Republican    44392
# Democrat      42068
# Name: Party, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
#importing the packages necessary for Data Preprocessing
#Regular expression
import re
#For string operations
import string
#Package for Natural language processing
import nltk
#For lemmatization
from nltk.stem.wordnet import WordNetLemmatizer
#To remove the stop words
from wordcloud import STOPWORDS

# %%
#counting those words which we don't need 
#initializaing each count to 0
url_count = 0
punc_count = 0
number_count = 0
mention_count = 0
other_than_character_count = 0

 
for i in range(len(df.Tweet)):#run the for loop till the end of tweet
    
  url_re = re.findall('http\S+',df.Tweet[i])
  url_count += len(url_re)
  punc_re = re.findall('[%s]',df.Tweet[i]) 
  punc_count += len(punc_re)
  num_re = re.findall('(\d+)', df.Tweet[i])
  number_count += len(num_re)
  mention_re = re.findall('@(\w+)', df.Tweet[i])
  mention_count += len(mention_re)
  alpha_re = re.findall("[^a-zA-Z]", df.Tweet[i])
  other_than_character_count += len(alpha_re)

print ("Count of url in tweet:", url_count)
print ("Count of punctuation in tweet:",punc_count)
print ("Count of numbers in tweet:",number_count)
print ("Count of mentions in tweet:",mention_count)
print ("Count of alphanum in tweet:",other_than_character_count)
# Out:
# Count of url in tweet: 68405
# Count of punctuation in tweet: 537631
# Count of numbers in tweet: 128691
# Count of mentions in tweet: 64786
# Count of alphanum in tweet: 2465479

# %%
def round1(data_str): 
    url_re = re.compile('http\S+') 
    punc_re = re.compile('[%s]' % re.escape(string.punctuation))
    num_re = re.compile('(\d+)')
    alpha_re = re.compile("[^a-zA-Z]")
    # convert to lowercase
    data_str = data_str.lower()
    # remove hyperlinks
    data_str = url_re.sub(' ', data_str)
    # remove punctuation
    data_str = punc_re.sub(' ', data_str)
    # remove numeric 'words'
    data_str = num_re.sub(' ', data_str)
    data_str = alpha_re.sub(' ', data_str)
    return data_str

# %%
#Performing lemmatization
def lemmatize(data_str):
    #initial index position for string 0
    list_pos = 0
    #intialize empty string to store the lemma words
    cleaned_str = ''
    #tokenize the sentence
    data_str = nltk.word_tokenize(data_str)
    lemma = nlp.WordNetLemmatizer()
    #for each word in sentence run a for loop and find the lemma word and add it to cleaned_str
    for word in data_str: 
        lem = lemma.lemmatize(word) 
        if list_pos == 0: 
            cleaned_str = lem 
        else:
            cleaned_str = cleaned_str + ' ' + lem
        list_pos += 1     
    return cleaned_str

# %%
#adding some more words to stopwords which was found during EDA process
STOPWORDS.add("rt")
STOPWORDS.add("s")
STOPWORDS.add("u")
STOPWORDS.add("amp")
STOPWORDS.add("th")
STOPWORDS.add("will")
STOPWORDS.add("t")
STOPWORDS.add("m")
STOPWORDS.add("ha")
STOPWORDS.add("wa")

# %%
# Removing stop words
def remove_stops(data_str):
    list_pos = 0
    cleaned_str = ''
    text = data_str.split()
    for word in text:
        #if word is not present in stopword add that to cleaned_str
        if word not in STOPWORDS:
            if list_pos == 0:
                cleaned_str = word
            else:
                cleaned_str = cleaned_str + ' ' + word
            list_pos += 1
    return cleaned_str

# %%
#Cleaning the data 
#empty list
data_clean = []
for i in range(len(df.Tweet)):
    #removing puntuation, links, numbers
    res = round1(df.Tweet[i])
    #removing the stopwords
    res1 = remove_stops(res)
    #performing lemmatization
    res2 = lemmatize(res1)
    data_clean.append(res2)

# %%
#cleaned Tweets
data_clean
# Out:
# ['today senate dems vote savetheinternet proud support similar netneutrality legislation house',
#  'winterhavensun winter haven resident alta vista teacher one several recognized repdarrensoto national teacher apprecia',
#  'nbclatino repdarrensoto noted hurricane maria left approximately billion damage congress allocated',
#  'nalcabpolicy meeting repdarrensoto thanks taking time meet latinoleader ed marucci guzman nalcabpolicy',
#  'vegalteno hurricane season start june st puerto rico readiness well pwr puertorico repdarrensoto espaillatny',
#  'emgageactionfl thank came orlando gala successful night possible without',
#  'hurricane maria left approx billion damage yet billion allocated rebuilding grid surpr',
#  'tharryry delighted repdarrensoto voting cra overrule fcc save netneutrality rule find',
#  'hispaniccaucus trump anti immigrant policy hurting small business across country find american willing',
#  'repstephmurphy great joining weareunidosus repdarrensoto roundtable orlando federal issue affecting central florid',
#  'allsaints fl zhihan john art received award year state competition found won congressional distr',
#  'realdonaldtrump official policy separate immigrant child mother definition cruelty',
#  'thank mom jean mother across nation raising future',
#  'paid respect nat l law enforcement officer memorial today lost sgt sam howard kissimmee',
#  'winterhavensun congratulation ahsbloodhounds senior abygayle rausch starting service country u naval acad',
#  'meet incredible young leader appointed u military academy district hispaniccaucus',
#  'wildlifeaction u wildlife decline florida specie snowy plover need advocate co sponsor recove',
#  'cheathwftv keeping gun wrong hand following wftv report repdarrensoto asks atf look called ghost gun fir',
#  'germienyc ty repdarrensoto calling hfanow ensure worker access paidsickdays matter live w',
#  'behind every successful student proud community family teacher great meet ocpsnews avalo',
#  'heardonthehill repdarrensoto recalled playing music dems caucus retreat repjoecrowley',
#  'nathanhale got meet repdarrensoto today classroomwhereithappens mrbettsclass avalonelem ocps gilder lehrman senbillnels',
#  'winterhavensun lead story polk news sun repdarrensoto senbillnelson november voter decide whether auto',
#  'fact percent american said didn fill prescription previous year high cost',
#  'american deserve abetterdeal cost prescription drug senior one allows medicare nego',
#  'thank billnye voice science planet sayfie hispaniccaucus audubonfl sierraclubfl',
#  'reprubengallego public comment responsibility federal agency public making critical land management decision',
#  'sat rollcall discus fellowship getting thing done congress band orange creek rider hikin',
#  'rvivian pulse memorial morning representing repdarrensoto beautiful ceremony honoring victim famili',
#  'joined colleague opposition trump admin adding citizenship question census accurate count cri',
#  'wftv repdarrensoto call regulatory reform ghostguns investigates story wftv',
#  'thank million bright hardworking teacher across america educating next generation leade',
#  'weareunidosus thank repdarrensoto joining u today discus devastating effect proposed cut snap',
#  'napaba repdarrensoto first puerto rican congressman florida brings napaba apahm congressional recepti',
#  'romancerookie repdarrensoto senbillnelson marcorubio need something insulin',
#  'waelalzayat thank repdarrensoto good friend avid supporter immigrant right emgagethehill emgageaction h',
#  'emgageactionfl repdarrensoto addressing team prepare emgagethehill emgageaction',
#  'news wkmg repdarrensoto talk district election justinwarmoth weekly see full interview',
#  'trump continues anti immigrant anti hispanic push ending tps honduran real solution pathway',
#  'yourbarriofl thank emerge usa hosting repdarrensoto',
#  'ricardorossello tambi n acompa en la entrega de estos tulos de propiedad tatacharbonier miguel romero repjorgenavarro v',
#  'senbillnelson got firsthand look ca o mart n pe ecosystem restoration project puerto rico today project designe',
#  'garywhite signed repdennisross repdarrensoto tomrooney',
#  'heavy heart mourn loss maria santiago burgos puerto rican survivor hurricanemaria',
#  'garywhite senbillnelson repdarrensoto discus restoration voting right felon census question town hall haine',
#  'senbillnelson good discussion tonight haines city reprichmond repdarrensoto amendment november ball',
#  'yourbarriofl vamos pr press conference rally repdarrensoto celebrating',
#  'mikewferguson haines city civil right forum touch voting right restoration felon speaki',
#  'tbhjr repdarrensoto wrote asking support growing nasa budget let invest future investing',
#  'demsespanol el congresista repdarrensoto fl asisti la celebraci n del festival y desfile puertorrique o de orlando demsatwor',
#  'floorcharts rep darren soto d florida twitter repdarrensoto march danger burn pit watch c span',
#  'lseabrookwftv received information repdarrensoto office conference call fema noon',
#  '',
#  'proud supported extension effort pr gov ricardorossello per fema map florida largest',
#  'breaking fema extended tsa housing voucher thru june pay flight back pr resettlement',
#  'housedemocrats repdarrensoto fl joined orlando puerto rican day parade festival demsatwork',
#  'prayer go fallen puerto rican national guardsman killed today plane crash family',
#  'cgagroup yesterday repdarrensoto visited cornerstone client kratossatellite expanded facility orlando spoke impor',
#  'garywhite fla pol tomrooney repdennisross garywhite roll call doesn count real estate nearly',
#  'norml thank repdarrensoto leadership others message federal official join ending federal marij',
#  'rabbi imam pastor walk room chat great convo w orlando wise guy twgradio today',
#  'garywhite senbillnelson join repdarrensoto town hall thursday haines city discus civil right restoration votin',
#  'aacnpolicy thank repdarrensoto cosponsoring title viii nursing workforce reauthorization act',
#  'demsespanol el senador marcorubio lo dicho la fraudulenta ley fiscal republicana lo esta ayudando la grandes corporaciones',
#  'joaquincastrotx last week joined repdarrensoto hispaniccaucus member press conference active military',
#  'mounted major push fl pr fed disaster relief education funding pr got fl still need',
#  'flcitrusmutual thanks repdarrensoto joining u april board meeting today bartow',
#  'el sentinel ayer el downtown de orlando estuvo lleno de folklor sica y sabor con la segunda parda y festival puertorrique o mira l',
#  'attended inspiring naacpocfl gala last night continue fight justice equality',
#  'mayorjosealvar parada puertorrique en downtown orlando con repdarrensoto osceola sherriff rus gibson osceolasheriff htt',
#  'carmelorios tambi n compartimos con el senador bill nelson y congresista darren soto quienes han sido grandes aliados de los boricuas',
#  'thanks sheriff russell gibson osceolasheriff office hosting gun return event unwanted gun',
#  'great chat w nalvarezwftv gwarmothwftv orlando pr parade thanks wftv hispaniccaucus',
#  'honored march u marine sgt lou boria puerto rican wwii korean war veteran orlando pr parade un',
#  'see la banderas flying know time orlando puertorican parade start wftv',
#  'madangel garywhite district includes e orange osceola e polk county take hour across',
#  'garywhite repdarrensoto host town hall thursday p haines city chamber cedric richmond chairman congressio',
#  'fla pol darren soto amendment make flying friendlier new mom pregnant woman via scottfist flapol ht',
#  'rvivian nd annual fl pr parade banquet representing repdarrensoto accepting godfather parade sash yourb',
#  'nbclatino repdarrensoto one many military family now find risk deportation torn',
#  'nbclatino repdarrensoto separate family contributed nation security unacceptable',
#  'fpizarro dc actualmente hay casi miembros de la fuerzas armada o veteranos con esposo que enfrentan una deportaci n congr',
#  'hispaniccaucus member demanding trump administration stop deporting active military veteran spouse military fami',
#  'repanthonybrown served iraq served side side patriotic american u documentation u',
#  'tune now facebook live press conference supporting military family preventing deportation vete',
#  'houseradiotv news conference repdarrensoto chc member et al military veteran spouse deportation medium rsvp oriana pi',
#  'debtcrisisorg doesn way supporter fighting end trillion studentdebtcrisis ret',
#  'underdogdreams repdarrensoto underdog dream first star academy central florida appreciate willingness listen learn',
#  'great host james barnes fla boilermakers ibbunion washington unitedwestand flaflcio',
#  'torilinder thank repdarrensoto working keepflwild',
#  'brycegibson thank bill rockwood repdarrensoto office time discus benefit golf big thanks rep',
#  'already cosponsor sarahtalkradio thank input unitedwestand',
#  'clean drinking water basic human right yr later flint family still use water filter',
#  'taracopp thurs usmc iraq vet army nationalguard wife alejandra juarez capitol hill w repdarrensoto icegov set',
#  'sure one day united state come back join paris climate agreement',
#  'let face planet b',
#  'need transition low carbon economy',
#  'child need make sure planet still hospitable year',
#  'prez macroninenglish boldly asserts face threat planet common good threat p',
#  'nicosgonzalez audubon julie hill gabriel evergladesjulie repdarrensoto guest macron speech joint',
#  'thanks fl wildcorridor carltonward joeguthrie mdimmitt journey highlight wildlife pass',
#  'welcome transportworker twu washington legislative conference great see everyone tonight',
#  'nature florida repdarrensoto take trail disney wilderness preserve launch florida wildlife corridor ex',
#  'marionmilitary surprise re nervous commandant asks see office really phone call yo',
#  'valenciacollege celebrating launch two new building valencia osceola campus coming soon career industry techn',
#  'audubonsociety audubon vice president water conservation julie hill gabriel honored join repdarrensoto french pr',
#  'prayer go canadian friend torontoattack especially life lost injured sensel',
#  'garywhite repdarrensoto invite julie hill gabriel nationalaudubon guest joint session congress french president',
#  'thanks historbilia environmental advocacy count fight protect enforce cleanairact',
#  'latimes chronicle push fema lease voucher pr evacuee sayfie hispaniccaucus',
#  'kqkellyq make sure call congressional member tell cut food assistance program hungry central florida fam',
#  'thank hero james shaw jr saving life wafflehouseshooting pray american died anothe',
#  'estatic rock earthday cafa caribbeanfusion cityofkissimmee onelove hispaniccaucus',
#  'honored host darius livingston st african american polk fire dept captain washington today theledger',
#  'caucusonclimate lost life million barrel spilled oil catastrophic loss wildlife habitat result deepw',
#  'prfaa fema acordado extender el programa tsa hasta mayo fema comunicado que se llevar n cabo desalojos en el d d',
#  'includes pr evacuee statewide',
#  'finally word hotel voucher extended pr evacuee family may',
#  '',
#  'florida faced yet another dreadful school shooting ocala today day student partake',
#  'jackpayneifas opinion darrensoto hlb challenge solve crisis scientific research grower ingenuity',
#  'miguel romero en la tarde de hoy trabajando junto al congresista darrensoto quien e un aliado en los asuntos de puerto rico y quie',
#  'daniaperiodista repdarrensoto se une al llamado del gobernador ricardorossello en la petici n fema para extender la asistencia tem',
#  'daniaperiodista repdarrensoto join governor ricardorossello petitioning fema extend temporary shelter assistance dozen',
#  'mikewferguson leah west staff member congressman darren soto repdarrensoto wife vice mayor inviting commis',
#  'intrigued host mikebloomberg re gun safety job bipartisanship washington today bpolitics housenewdems',
#  'prfaa regarding tsa extension fema informed u decision request unconditionally extend program n',
#  'nadeennews read letter sent fema asking extension tsa program allowing family puerto rico stay',
#  'nadeennews family one hundred fl repdarrensoto working lawmaker including marcorubio senbillnelson',
#  'nrdems breaking trump admin moving country closer opening arcticrefuge drilling house dems sent letter',
#  'carlosvotero cientos de familias puertorrique desesperadas por el fin de la ayuda para albergue de fema',
#  'trschatz reunido junto la senadora nayda venegas con el congresista darren soto',
#  'orlpolitics rep soto kissimmee river bill pass house unanimous consent sayfie opo',
#  'nikkifried realdonaldtrump administration showing inhumanity need compassion repdarrensoto thank stepping',
#  'alzadvocatefl day isn complete w o thanking repdarrensoto agreeing cosponsor boldalzheimersact honored eve',
#  'carltonward great work repdarrensoto keepflwild protect fl wildcorridor',
#  'davidbegnaud today power outage across puerto rico caused cobra energy private contractor hit transmi',
#  'garywhite repdarrensoto say bill promoted unanimously passed house first step toward protecting kissimmee river wil',
#  'pollutingpruitt proposed drastic budget cut epa program protect american health environment',
#  'continue work prfaa resolve matter fema quickly help family',
#  'emv repdarrensoto sez snapmatters serf fl well bc resident struggle w high housing cost low wage opposes farmbill w',
#  'islandwide blackout pr proof realdonaldtrump congress underfunded disaster relief',
#  'ruralco repdarrensoto proposed snapmatters cut categorical eligibility biggest impact state florida fwafl',
#  'oceanchampions ocean champion repdarrensoto new kissimmee river bill major boost ecosystem restoration florida hou',
#  'gop farm bill kick floridian food assistance snap state thedemocrats',
#  'govtrack h repdarrensoto passed house yesterday senate kissimmee river wild scenic river study act htt',
#  'houstontaylorat timely relevant opinion column repdarrensoto agriculture florida nd largest industry hidden',
#  'cardiology thank repjoewilson reperikpaulsen repstephmurphy repdarrensoto supporting h advancing care',
#  'keepflfishing repdarrensoto historic kissimmee river heart central florida water drainage route',
#  'natresources legislative hearing marine conservation shark fishery regulation repdarrensoto h repwebster h',
#  'ssnalerts darrensoto kissimmee river wild scenic river study act pass house without opposition',
#  'taxday big corporation top getting huge tax break goptaxscam cut crucial benefit',
#  'read op ed theledger re future agriculture technology lie central florida orlandosentinel',
#  'passed kissimmee river protection bill congress today sayfie orlandosentinel theledger osceolanews',
#  'hispaniccaucus right now still apply renew daca meet requirement apply daca renewal',
#  'wusfschreiner moment took picture fl wildcorridor member joeguthrie mdimmitt along wusf stevenewbo',
#  'heraldtribune cite letter w tedyoho join call speedier hurricane relief fund citrus grower',
#  'great catch w fl wildlife corridor team mdimmitt joeguthrie carltonward fl begin',
#  'anahihurtado new article loved hearing repdarrensoto repjenniffer last night event make proud',
#  'estatic speak alma mater fla hispanic community bipartisan work pr gwhatchet repjenniffer',
#  'cleanairmoms fl repdarrensoto thank standing health telling epascottpruitt enough enough polluti',
#  'gwululac tweet facebook post take continual effort make change don vote don spea',
#  'ehvalinnn abrazos todos help others repdarrensoto',
#  'diegs pleasure witness bipartisan discussion future latino constructive politics repdarrensoto rep',
#  'cgmiamiharper thank repdarrensoto another good discussion florida canada relation quarter billion award winner y',
#  'repjenniffer fellow congressman repdarrensoto participating panel latino future constructive politics',
#  'gwcisneros common need district bind u together across aisle repdarrensoto',
#  'gwululac fear debate disservice repdarrensoto',
#  'jenniffer ahora junto al colega congresista repdarrensoto en el panel de discusi n latino future constructive polit',
#  'rvivian civil right award ceremony banquet orlando hrc orlando lachicamayra jodeelive repdarrensoto valeriesoto',
#  'speaking w student alma mater along repjenniffer future constructive politics la',
#  'guygilady great meeting director yourbarriofl repdarrensoto team discus cooperation israel america',
#  'yom hashoah recognize holocaustremembranceday remember million jewish life lost million v',
#  'great host florida electrical worker ibew dc week united stand aflcio flaflcio',
#  'mrfisk senbillnelson repdarrensoto need real net neutrality please pas permanent net neutrality law',
#  'rvivian oneorlando alliance reception venue hrc orlando repdarrensoto yourbarriofl fdpmoneygirl kenevansdncfl',
#  'oppose adding citizenship question census suppress participation florida mil immig',
#  'rvivian hrc cfsc planet hollywood repdarrensoto yourbarriofl hrc orlando jodeelive izamontalvonews watermarkonline',
#  'read passionate town hall gun safety thanks everyone attended osceolanews housenewdems',
#  'gracenapolitano standing w hispaniccaucus colleague voice serious concern commerce dept wrong decision',
#  'rvivian hispanicfed betsy franceschini staff betsyfranceschi milvzqz ricardoj na pbcdhc repdarrensoto somos',
#  'rvivian manicuremovement event osceola sheriff rus gibson repdarrensoto izamontalvonews pbcdhc yourbarriofl trip',
#  'watch today pm et hispaniccaucus press conference mounting concern trump',
#  'read op ed orlandoweekly caring child born parent addicted opioids orlandosentinel',
#  'enrique served county count u fight daniel hispaniccaucus',
#  'hispaniccaucus atenci n dreamer actualmente n puedes solicitar la renovaci n de tu permiso daca si cumples con los requisitos p',
#  'fema awarded major pr recovery job new unprepared firm failed deliver exacerbated damage',
#  'proud co sponsor fair pay act paycheck fairness act pay equity act',
#  'woman average still earn cent every dollar earned men pay gap worse woman color',
#  'rvivian repdarrensoto puerto rico task force job fair kissimmee roxdelariva pbcdhc izamontalvonews lachicamayra hrc orl',
#  'rvivian repdarrensoto puerto rico task force kissimmee yourbarriofl lachicamayra liana guerra roxdelariva ceciliafigueroa',
#  'yourbarriofl thank pwmspirates hosting repdarrensoto parkway middle school kissimmee',
#  'adrienneegolf thank repdarrensoto holding town hall today gun safety inviting momsdemand speak comm',
#  'johnreichardwes rwitherspoon participated great town hall meeting called repdarrensoto osceola county fl finding way',
#  'rvivian repdarrensoto gun safety town hall st cloud pbcdhc repdarrensoto yourbarriofl fdpmoneygirl liana guerra hrc orl',
#  'yourbarriofl packed gun safety town hall st cloud repdarrensoto momsdemand gunsense',
#  'osceolasheriff sheriffrussgibson repdarrensoto engage st cloud community guncontrol townhall',
#  'jaygalbraith nytimes article valenciacollege valenciagiving student perspective middle class family increasingly look',
#  'beach nole thank repdarrensoto book visit student loved meeting always welcomed pirat',
#  'proud honor vietnam vet memorial pin ceremony tomorrow deptvetaffairs monument lake nona',
#  'congrats month nevadawomaninstem cristina rocha rodriguez currently student csncoyote',
#  'tech sector employ million woman minority sharply underrepresented embracing diversity b',
#  'congratulation go goldenknights victory jet western conference final keep',
#  'ramadan mubarak family celebrate holy day across nevada world',
#  'thank capac inviting year gala apahm nevada home one fastest growing',
#  'happy birthday city love vega',
#  'policeweek show appreciation brave officer put life line day kee',
#  'admin decision repeal net neutrality give internet service provider ability stack deck',
#  'great addition nv',
#  'lvmpd police unity tour team vega washington d c policeweek team across country ride d c leading',
#  'cyber attack becoming frequent nefarious eliminating top white house cybersecurity job',
#  'coralacademylv celebrated year serving community spring gala re happy first',
#  'porque ninguna madre debe de ser arrebatada de su hijo honorimmigrantmoms',
#  'mother taken away child honorimmigrantmoms',
#  'happy mothersday loving caring hardworking mom nevada',
#  'comment false offensive demonstrate yet ill informed anti immigrant',
#  'lvchamber chamber ceo mbsewald appreciate entire nv congressional delegation repdinatitus markamodeinv repjackyrosen repkihu',
#  'thank men woman support stand loved one day serve sacrifice o',
#  'proud year graduate unlv latino graduation staff able present newly minted gr',
#  'congrats bgcsnv nevadahandlv lssnv working together create innovative environment bould',
#  'congratulation scholarship recipient annual asian scholar banquet hosted lasvegasacc',
#  'feliz d de la madre toda la madres que lo celebran hoy apreciemos el cari o el cuidado y el trabajo duro de',
#  'happy birthday nsf code girl stem bill create new nsf grant fund program',
#  'lcvoters appreciate speaking leading fight yuccamountain repjackyrosen',
#  'deeply disappointed see republican controlled congress vote ship radioactive nuclear waste across',
#  'yucca mountain dangerous costly ill conceived plan pose direct threat health safety',
#  'craigcaplan cspan repdinatitus repkihuen repjackyrosen d nv urge congress stop wasting time taxpayer money yucca',
#  'amendment help u stop reckless project shedding light dangerous fe',
#  'garymartindc repjackyrosen tell secretaryperry developing yucca mountain nation nuclear waste repository prev',
#  'undermining snap farmbill deal blow nevadan need access snap help feed famili',
#  'fcc process ending net neutrality million american supporting legislation',
#  'yucca mountain threaten national security interfering military testing training asked secr',
#  'couldn prouder join repohalleran investing teacher education investment ameri',
#  'icymi watch testimony today house rule committee yuccamountain',
#  'proud join colleague calling day comment period epa selective science',
#  'need forward thinking solution tackle issue amendment help u turn site somethin',
#  'productive meeting today adl national hate discrimination place community',
#  'amendment prevent energy moving forward dangerous repository plan omb considers num',
#  'yuccamountain mean nearly rail cask nuclear waste traveling site across country throu',
#  'map proposed route look member representing district conse',
#  'yuccamountain require moving ten thousand metric ton radioactive waste across country southern nevada',
#  'testify front house rule committee yuccamountain watch live',
#  'special thanks nevada hospital association stopping office today continue fighting prot',
#  'happy teacherappreciationday nv wonderful teacher thank dedication kid',
#  'nationaltourismweek travel tourism transformed economy southern nevada vega nv ustravel',
#  'congratulation goldenknights making western conference final hard work paying',
#  'yesterday celebrated cincodemayo year festival parade north la vega thank inviting',
#  'icymi read fighting protect nevada solar job',
#  'armando constituent nv reached office status application naturalization',
#  'al acabar con tps para los hondure o la adm n de trump amenaza con desarraigar familias que han hecho vidas por',
#  'terminating tps honduran threatens uproot family made life',
#  'may besides legendary contribution contemporary culture starwars greatly cont',
#  'amendment repurpose yucca mountain filed need smart solution tackle dangerous costl',
#  'jewish value tzedakah tikkun olam something try live every day reflect',
#  'incredible girlswhocode',
#  'need better job fighting sexual harassment senwarren introduced sunlight workplac',
#  'congrats award recipient week sba nevada expo award luncheon great opportunity f',
#  'wonderful exhibition evening sahara west library must protect nevada natural beauty outdoor',
#  'know federal government award significant percent contracting opportunity small busine',
#  'trump administration plan slash ppfa titlex funding threaten health low income woman',
#  'congratulation garrettjuniorhs principal jamey hood named nevada middle school principal',
#  'district staff presented al association nevada chapter certificate ribbon cutting ceremony tog',
#  'snhba snhba nahbhome met repjackyrosen nahb bringing housing home week spoke congresswoman import',
#  'un de mi colegas en mandarle una carta secnielsen para que extienda tps individuos de honduras quie',
#  'us john f kennedy now structurally complete scheduled launch next year looking forward',
#  'la renovaci n de daca sigue disponible su tu estatus se venci el de septiembre de o despu la solicitud',
#  'renewal daca still available status expired september application renewal',
#  'need better job fighting sexual harassment workplace read senwarren say',
#  'simply unacceptable grateful countless woman victim coming forward share st',
#  'congrats goldenknights impressive victory nv rooting',
#  'sbagov district office across country dedicated helping entrepreneur create develop busines',
#  'clarkcountysch congratulation winner congressional art award ceremony rosenfornevada congressional distri',
#  'internationalworkersday celebrating hardworking family nv let recommit promoting wo',
#  'month recognize long history asian american pacific islander community nevada excit',
#  'congrats year congressionalartcompetition winner nv tina yun coronado kayla espinal',
#  'may militaryappreciationmonth serving served thank honor recognize',
#  'great turnout year lvwtechawards hosted ncwit vega must continue work closing gender',
#  'special shout new graduate participated weekend annual graduasian aapi gra',
#  'happy national smallbusinessweek know nevada small business employ people check ou',
#  'podemos darles la espalda nuestros vecinos copatrocinado un proyecto de ley que le dar los beneficiar',
#  'despu de sobrevivir los horrores de la guerra civil salvadore los due o de restaurante flor campos y jos alv',
#  'nevadan made clear consent storing nation nuclear waste backyard time',
#  'turn back neighbor ve co sponsored bill provide tps holder flor jose',
#  'surviving horror salvadoran war la vega restaurateur flor campos jose alvarado came',
#  'amendment co sponsored faa reauthorization act help ensure woman greater presence',
#  'congratulation teacher staff presented certificate work southwest career',
#  'weekend robotics team lasvegasacademy cimarronspartan sierra vista h lake mead christian academy',
#  'district staff wore denim honor year denimday special thanks rapecrisisctrlv helping',
#  'week alzassociation held annual southern nevada educational conference discus fight alzh',
#  'icymi op ed thehill highlight bipartisan legislation introduced past week repeal trump admin',
#  'glad join colleague repmccaul repteddeutch helping pas bipartisan legislation hold iran account',
#  'protecting nevada public land important preserving outdoor treasure vital maintain',
#  'representative woman mining coalition visited office today discussed mining issue impor',
#  'introduced job waste act legislation prohibit energy moving forward dangerou',
#  'caring senior always personal always remain top priority mine met',
#  'seia great op ed repjackyrosen importance repealing trumptariffs solar protect american worker clean en',
#  'solar technology driving future clean energy nevadan american everywhere need policy w',
#  'la renovaci n de daca sigue disponible su tu estatus se venci el de septiembre de o despu la solicitud',
#  'renewal daca still available status expired september application renewal',
#  'attempt revive yucca mountain threatens health safety nevadan fighting adminis',
#  'proud participant year denimday courage persistence hold power put',
#  'honor congress welcome emmanuelmacron capitol today france america first ally',
#  've offered two amendment faa reauthorization act ensure nation airline passenger',
#  'air traffic controller airport security officer work around clock keep sky safe',
#  'protecting woman access affordable health service community critical stand',
#  'la decisi n del fiscal general jeff session de eliminar un programa de ayuda legal para los inmigrantes e muy pre',
#  'sure take advantage nationalparkweek taking time explore nevada natural wonder lakemeadnps',
#  'sharing story october tragedy community able come together grieve heal',
#  'today mark armeniangenocide remembrance day forget horror past signed onto',
#  'el xito de la energ solar en nevada reforzado nuestra econom esta administraci n amenaza este xito con la',
#  'solarindustry bipartisan bill supported seia seek repeal trump administration solar tariff rep',
#  'fcc began rolling back netneutrality today isps now able stop slow connectivity fo',
#  'administration misguided decision level tariff solar panel threatens hurt thousand nevada wo',
#  'joining colleague co sponsoring legislation calling epascottpruitt resign tenure inexcu',
#  'e org attack solar energy attack countless hardworking nevadan benefit growing industry new bi',
#  'earthday working conserve public land future generation enjoy make nev',
#  'cchmuseum turned week thank preserving history helping tell nevada story generation come',
#  'congratulation bouldercitylib year service boulder city community nationallibraryweek nv',
#  'clarkcountynv thank repjackyrosen staff recognizing clarkcounty museum anniversary rep rosen sp',
#  'want stay date fighting nv sign newsletter following link gt gt',
#  'opioid overdoses become one leading cause death country killing average american',
#  'seia thank repjackyrosen repsanfordsc rephuffman repralphnorman steveknight fighting protect american solar wo',
#  'seia bipartisan legislation important step countering harmful economic impact trumptariffs',
#  'administration directly threatened nevada solar job president imposed percent tariff importe',
#  'attack solar energy attack countless hardworking nevadan american across country ben',
#  'april st mark beginning nationalparkweek celebrate national park free saturday take',
#  'every day someone get perfect score act special shout nv constituent dante car',
#  'cathcharitieslv thank repjackyrosen meeting deacon tom important issue facing nevada',
#  'epascottpruitt tenure office filled anti environmental policy federal investigation ethic',
#  'congratulation csncoyote designated national center academic excellence cyber defense educat',
#  'physic mathematics computer science highest male bias woman outnumbered',
#  'happy yom atzmaut dearest friend israel bond connecting israel unshakable',
#  'solar energy success nevada led new job cheaper power bill growth new industry di',
#  'four month thejusticedept decided suspend legal assistance program educates detained im',
#  'great meeting nvrestaurants today hospitality backbone nevada economy restaurant',
#  'congratulation former intern unevadareno junior kate groesbeck recently named unr newest',
#  'los adores de nevada han esperado demasiado tiempo por una soluci n legislativa para la incertidumbre que impact',
#  'thonyavellaneda declaraci n de repjackyrosen sobre un nuevo esfuerzo por votar una posible soluci n para los dreamer daca',
#  'nevada dreamer waited far long legislative solution uncertainty impact daily l',
#  'spoke cee luncheon today recognized incredible work provide thousand underserved student',
#  'productive meeting nevada trucking association today strong trucking industry essential',
#  'reminder district office host mobile office hour today heritage park senior facility stop',
#  'first lady barbara bush exceptional american lasting impact country endure sending cond',
#  'weekend aid walk district staff recognized afanlv executive director antioco carrillo',
#  'baseless assertion marijuana lead opioid addiction repeat tired widely debunked argument c',
#  'taxday house passed legislation ve co sponsored permanently fund service help low incom',
#  'online security privacy issue relevant now fighting restore internet privac',
#  'nevada dreamer contribute community make u stronger thank astrid nv standing immi',
#  'congrats impressive victory goldenknights re one step closer making history',
#  'incredible news glad see tourism economy continue grow succeed',
#  'reminder district office mobile office hour wednesday april heritage park senior fa',
#  'joining marchforscience today stand nevadan believe science inform policy',
#  'happy baisakhi today honor history many contribution sikh community wish everyone celebratin',
#  'district office mobile office hour wednesday april heritage park senior facility stop',
#  'supporting bipartisan legislation protect special counsel fired without cause',
#  'welcome congressman conorlambpa',
#  'connorobriennh jacky rosen asks whether circumstance u restart ground nuclear testing say',
#  'white house plan fund wasteful wall money defense department threatens military readin',
#  'great meet aaaj aajc today nevada aapi immigrant family make community stronger proud',
#  'congrats goldenknights first playoff victory nevada couldn prouder keep hard work',
#  'great meeting nevadabar president gene leverty stopped office today discus funding',
#  'nv opioid overdoses leading cause drug related death urging house appropriator help equip la',
#  'holocaustremembranceweek weremember million jew lost life holocaust',
#  'enjoyed meeting nevada cattleman association hear ranching play pivotal role',
#  'trump admin stop nothing undermine health care system cmsgov recent rule change lower p',
#  'today mark anniversary fair housing act even though step right direction stil',
#  'former ambassador diplomat raised alarm corrosion statedept threaten',
#  'meeting ibew representative talked way improve nevada infrastructure thank fo',
#  'scrubbing information breast cancer show little administration ca',
#  'new bill create job tech startup providing tax credit small business hire worker re',
#  'accurate census important must protect integrity administration move politicize',
#  'today met emergency medical service em personnel nevada thanked hard work d',
#  'congratulation winner coral academy science rd annual girl math tournament proud wha',
#  'lwcfcoalition thank repjackyrosen supporting permanent reauthorization lwcf read lwcf important',
#  'todav est n disponibles la solicitude para renovar daca si previamente recibiste daca y se venci el de se',
#  'application still available renew daca previously received daca daca expired',
#  'glad see cecilia g mez return home safely son supportive community',
#  'nevada woman make average cent every dollar man make gap even wider woman color',
#  'proud veteran deserve better act earned ascassociation endorsement sacrificed many',
#  'nationalretirementplanningweek ahead learning financing retirement',
#  'read new op ed conservation protecting public land preserving heritage way o',
#  'cleanairmoms couldn said better repjackyrosen epascottpruitt isn effective reckless corrupt',
#  'mbsewald lvchamber salute repjackyrosen award uschamber eggsandissues teamchamber nick clause capture moment',
#  'lvchamber rosen propose tax credit boost tech startup great article lasvegassun eggsandissues breakfast',
#  'senator akaka champion hawaiian dedicated public servant loved many memory',
#  'cecilia g mez contribuy la comunidad por d cadas crio hijos y estaba en camino obtener la residencia perm',
#  'ice focus time resource hardened criminal threaten safety community stop teari',
#  'cecilia g mez contributed community decade raised son path gaining legal permanent residency',
#  'thank support bill reprokhanna stem field leading future diversity key ensur',
#  'bill offer tax credit tech startup research development small business hire mo',
#  'urging everyone join autismawarenessmonth push continued acceptance million people',
#  'heart go maj stephen del bagno family loved one community mourns always',
#  'epascottpruitt mounting scandal make impossible lead epa anti environmental agenda',
#  'spoke lvchamber egg issue breakfast today announced new bill aimed creating tech startup d',
#  'today mark goldstarspousesday day dedicated remembering courage strength spouse whose wife',
#  'lvchamber re room nv power player morning hon shelley berkeley touronevada repjackyrosen chairman mike bolo',
#  'gretatweeted repjackyrosen talking yucca mountain continue fight every step way eggsandissues lvchamber ht',
#  'adpikelly nv congresswoman repjackyrosen speaks lvchamber morning priority southern nevada public safet',
#  'lvchamber congratulation repjackyrosen awarded spirit enterprise award uschamber eggsandissues',
#  'lvchamber welcome repjackyrosen egg issue smithcenterlv discussing bipartisan work member prob',
#  'gmitter actionnewsjax wjxt fcn go',
#  'published fsu v boise game huge win jacksonville',
#  'stand together one nation god extend heartfelt wish muslim community',
#  'heart go family colleague loved one jacksonville police officer passed away',
#  'providing remuneration survivor descendant rosewood massacre one greatest piece',
#  'mother day celebrate first welcome u world mother first role mod',
#  'congressmanraja gop farm bill slash snap premiere anti hunger program billion meal snap predece',
#  'officialcbc cbc chairman reprichmond sign page jobsandjustice act press conference thursday may',
#  'happy support jtafla passenger ferry grant help secure usdot fund',
#  'tallahassee southside farmer market great resource resident area today grand opening w',
#  'officialcbc today et cbc introduce jobsandjustice act omnibus legislation passed increase',
#  'heartbreaking baker gone passing daughter shanique told',
#  'congratulation duvalschools stantonprep freshman jaylen thomas winner florida fifth congressional',
#  'great morning farmshare quincy able feed several family today activity',
#  'freedom free driven child activist john due congratulation',
#  'morning annual national day prayer event jacksonville city hall inspiring thank',
#  'officialcbc join u tuesday may pm est cbcdemandsjustice twitter town hall community policing',
#  'moreartculture last night congressional district artistic discovery high school art competition huge success',
#  'great finally meet taylor',
#  'new town pharmacy jacksonville serf vital resource undeserved community pharmacy offer free',
#  'may national military appreciation month time honor outstanding service brave men woman',
#  'proud voice support small business celebrate contribution neighborhood today',
#  'nothing small impact smallbiz american economy family owned operated economy dr',
#  '',
#  'humbled stand florida delegation moment silence honor sergeant noel ramirez dep',
#  'flint water crisis wake call lead poisoning real danger must taken seriously fou',
#  'great meeting president emmanuelmacron today joint meeting congress',
#  'floridastate know fsu college law offer free legal service veteran family learn progr',
#  'congrats military academy nominee alexander sobeski appointment westpoint usma',
#  'otd eight year ago deepwaterdisaster spill unleashed five million barrel oil gulf mexico',
#  'repcheri houseagnews hey houseagnews housegop fixed harmbill notafarmbill',
#  'urge republican work democrat negotiate compromise farmbill weaken ability f',
#  'moreover farmbill fails invest rural development bioenergy program undermines conservation effort',
#  'disappointed house republican chosen mark partisan farmbill includes severe cut',
#  'dsolisagecon famu agribusiness program student opportunity meet interact top policymakers',
#  'nearly million american struggle put food table day including five million senior',
#  'gop house farmbill gut nearly billion snap nation important effective anti hunger',
#  'repanthonybrown reducing poverty moral obligation common sense poverty cost economy trillion dollar goptaxsc',
#  'price prescription drug gas health insurance skyrocket goptaxscam isn helping florida w',
#  'congrats military academy nominee michael flores appointment merchant marine academy',
#  'flstatesociety delegation wonderful time celebrating cherry blossom season last night thanks repallawsonjr boar',
#  'great see officialmlk today congressional ceremony honoring life legacy rev dr',
#  'today honor six million life lost holocaust yomhashoah',
#  'irma might retired still working hard filed claim fema still need help',
#  'today mark half century signing fair housing act ended legal segregation housing',
#  'nothing important ensuring worker receive equal pay equal work average woman',
#  'reploisfrankel equalpayday recognizes woman must work extra month earn pay men closing genderwagega',
#  'national retirement planning week take action better future start planning today',
#  'spending bill included funding provision requested help elderly got additional millio',
#  'good luck alma mater famu hcasc national championship weekend competition highlight',
#  'repjohnlewis year ago today learned painful news friend mentor dr martin luther king jr assassinat',
#  'otd lost great leader work helped forever move country forward may great dream martin l',
#  'nat l science foundation decision award mag lab floridastate next yr tremend',
#  'honor worldautismawarenessday let lightitupblue congress liub',
#  'pleasure speaking vietnamwar commemoration ceremony tallahassee national cemetery',
#  'staff following hearing jax boardroom classroom woman brought u',
#  'decision add citizenship question census long lasting consequence city sta',
#  'including citizenship question census serf suppress participation result inaccura',
#  'visited famu repanthonybrown repadams explore relationship hbcus',
#  'thetinydiplomat astrostarbright bravery mag allawsonjr ava stormreid wrinkleintime firstbook maejemison',
#  'one teach one',
#  'uncf uncf vp public policy government affair campus famu repanthonybrown repadams repallawsonjr fo',
#  'wonderful see many student engaged interested ag issue discussed',
#  'honor life linda brown whose courage opened america eye show separate mean equal lega',
#  'dare powerful use strength service vision becomes le le importan',
#  'mitchell scholarship program application year postgraduate study ireland now open application d',
#  'biggreenpen acronym heard saturday farmersroundtable repallawsonjr rep collin peterson nap elap rma arc plc',
#  'know udoka azubuike attended potter house christian academy jacksonville becoming kansa',
#  'hosted farmersroundtable address issue affecting nation agricultural industry met local',
#  'decatur county nothing without ag appreciate agriculture georgia farmersroundtable',
#  'attendee holmes county appreciate counterpart board assure h',
#  'ag committee ranking member peterson need everyone agriculture crop insurance farmersroundtable fl',
#  'ag committee ranking member peterson take suggestion back dc u take back',
#  'great thing taking place today farmer roundtable congressman peterson joined hosting today',
#  'proud youth today rallying gun violence generation nelson mandela',
#  'year affordable care act became law result historically low uninsured rate',
#  'calling art teacher invite student participate congressional art cont',
#  'join u farmersroundtable tccworkforce tallahassee house ag ranking member rep pet',
#  'join farmersroundtable tccworkforce tallahassee house ag committee ranking member',
#  'let go fsuhoops sweetsixteen marchmadness gonoles',
#  'treat meet st paul ame church girl scout cluster visit dc',
#  'glad stop',
#  'dsolisagecon farmbill important famu landgrant univesity program famu funded b',
#  'gumedicine iconic view heading office repcardenas marcorubio repallawsonjr afternoon healthjustice ht',
#  'join u farmersroundtable saturday tccworkforce house ag committee ranking member rep collin pe',
#  'chance chat w victoria moore famu cbcf japan studyabroad pre departure reception',
#  'casework problem va postal uscis social security federal issue staff offi',
#  'great meeting jtafla discus funding first coast flyer sw route final step',
#  'woman make history america move forward congratulation repmarcykaptur becoming longest serving wom',
#  'congrats military academy nominee carina richardson appointed naval academy carina',
#  'shawn devries thanks repallawsonjr taking time today meet u continued support nothing net nbn',
#  'six month hurricanemaria ten thousand american citizen remain w o permanent shelter water el',
#  'extend deepest sympathy family master sgt william posch jacksonville staff sgt carl eni',
#  'farmersroundtable saturday tallahassee community college center workforce development hope',
#  'pleased part ne woman veteran recognition gala jacksonville fl host nation rd large',
#  'congratulation florida state seminole great victory xavier advance sweet',
#  'join next saturday farmersroundtable tallahassee community college center workforce develop',
#  'washington community college national legislative summit gototcc president jim murdaugh tcc',
#  'join u farmersroundtable tallahassee community college center workforce development h',
#  'famuext hbcudigest landgrant nlfrta blackfarmersusa famu sustainfamu thank sharing',
#  'keneshiagrant look fl first gen matching grant scholarship got bump budget worked jebbush al',
#  'proud stand solidarity student today say neveragain gun violence tolerated',
#  'spoke sbdcatunf regional director janice donaldson following smallbusiness committee field hearing',
#  'join u farmersroundtable tallahassee community college center workforce development h',
#  'proud stand america student voice making difference fight action prevent gun vi',
#  'member dstinc met staff office today part annual delta day nation',
#  'local public school greatest historic asset nation hold highest potential preparing',
#  'housedemocrats child lost life gun violence sandy hook many must lose congress take',
#  'reason rep kycomer work behalf duty representative washi',
#  'hillary almond small business owner eight employee ensure eight family taken care',
#  'jasonrothfl good see congressman allawsonjr congressman kycomer jaxchamber morning talking resource min',
#  'dane grey president ceo eliteparkingsoa company seen success accessing much needed cap',
#  'jaxalliance standing room today small business committee field hearing repallawsonjr rep kycomer jax chamber',
#  'important remember lending sba significant woman minority business owner ne',
#  'lawson evidence suggests economy growing much largely due woman minority owned business',
#  'join house small business committee hearing march jaxchamber examine chall',
#  'join house small business committee hearing march jaxchamber examine chall',
#  'fsusfloridahigh class visited washingtondc junior class trip student made stop',
#  'join u farmersroundtable tcc center workforce development pm house agriculture co',
#  'quorumanalytics quorum sat repallawsonjr first behindthedesk video talked experience freshman',
#  'carinarichardson us voice advocate peer internationalwomensday womenshistorymonth',
#  'astrostarbright shining star jacksonville community internationalwomensday womenshistorymonth',
#  'saphicher leading charge snap facilitator floridastate campus helping student apply fo',
#  'internationalwomensday let u take moment recognize contribution woman made continue',
#  'time woman stand without knowing possibly without claiming stand w',
#  'essay contest alert african american high school student important choose path college',
#  'housesbcdems repallawsonjr role environmental protection mitigating man made disaster gulf oil',
#  'join house small business committee hearing march jaxchamber examine chall',
#  'rd anniversary bloodysunday honor foot soldier sacrificed life bring forth chan',
#  'high school student interested attending one united state military service academy offi',
#  'repwilson great pleasure join force week repallawsonjr repnealdunn help boost state top economic',
#  'recently met floridastate student saphicher gonzalez elena princi tallahassee fsusga senator saphic',
#  'great briefing week w officialcbc feedingamerica marthastableorg foodbank nyc toendhunger discus',
#  'great basketball game last night famu rattler bethunecookman wildcat meac famu',
#  'hunger feedingamerica team thanks repallawsonjr officialcbc highlighting impact food insecurity community',
# ...
#  're reading remember thankateacher teacherappreciationweek',
#  'right now joining edworkforcedems important subcommittee hearing addressing nation growing',
#  'bill aim increase retirement saving providing employer employee another tool save',
#  'morning proud join bgov colleague repwalberg engaging conversation bill',
#  'repwalberg glad join repbrochester bgov morning discussion bipartisan legislation help strengthen reti',
#  'thirdwaytweet must prepare workforce w skill needed thrive changing economy say repbrochester read big',
#  'delaware thankful seniorcorps volunteer dedicate time mentoring underserved youth helpi',
#  'edworkforcedems agree congress need fixfasfa support repbrochester simple fasfa act remove bar',
#  'patciarrocchi realromadowney padua academy repbrochester night woman achievement',
#  'first state begin warm increase smog make breathing difficult poor air quality hea',
#  'according nidanews american die opioid overdose every day',
#  'yesterday opportunity talk delaware ddc legislation policy affect delawarean',
#  'proud johncarneyde joining important consortium critical work together across state',
#  'chriscoons re hour away senatorcarper repbrochester seasonal sussexcounty job fair stop rehoboth beach conve',
#  'administration required accept new daca applicant uphold current law keep working towar',
#  'trump decision strip dreamer protected status struck court',
#  'need help va irs social security another agency team hosting casework hour georget',
#  'visit part bpc bipartisan american congressional exchange enjoyed food learning fro',
#  'friday toured william pennhs farm table program friend rep rodneydavis program provides',
#  'celebrate clean air clean water clean land one earth u protect one',
#  'bpc bipartisan privilege coordinate another american congressional exchange visit w repbrochester rodneydavis delawa',
#  'future agriculture bright today rodneydavis visited corteva learn using',
#  'earlier week opportunity share story empowerment nc bwde proud par',
#  'though tragic thankful hero tammie jo shults nerve steel preventing',
#  'great see friend chriscoons senatorcarper agriculturede secretary michael scuse annual',
#  'good government good use taxpayer dollar people delaware sent advo',
#  'houseagnews concerned getting policy right let develop program feed people',
#  'happens child get sick car break mean child go hungry',
#  'top re creating workrequirements don sufficiently take account challenge people fa',
#  'estimated ll need additional million slot workforce training program proposal w',
#  'de former secretary labor think ill advised scale massive employment training program',
#  'question houseagnews re concerned getting policy right aren taking',
#  'believe work believe work strong proponent workforce development program',
#  'doesn benefit country certainly doesn benefit farmer working family delaware farmbill',
#  'excited join urban rural coalition traditionally made process bipartisan one',
#  'love farm bill ag general comprehensive urban rural global',
#  'watch farmbill opening statement live',
#  'de agriculture contributes job b yearly economic activity mean lot state',
#  'pleasure talking connection research federal policy wesley college student',
#  'historically significant day sikh wishing sikh american friend happy vaisakhi',
#  'today holocaust remembrance day pause around world remember million life lost hol',
#  'fun time taking selfies jamming bruno mar kaylascourt delaware miss amazing',
#  'opportunity welcome student delaware h office today talk first state proud',
#  'believe everyone deserves access nutritious healthy food work alongside colleague',
#  'morning honored join amprog moving discussion proposed change snap program',
#  'proud co sponsor paycheckfairnessact taking stand working woman family bi',
#  'delaware re performing better national average must press equalpaynow ensure',
#  'based current rate woman wage won equal men year one day pay inequality',
#  'wagegap widens woman color african american woman earn latinas earn eve',
#  'across country working woman face wage discrimination impact livelihood family thei',
#  'intern play critical role helping serve people delaware recently took lunch',
#  'worldhealthday half world population life without access essential health service',
#  'glad see many folk come discus find common ground gunreform morning',
#  'thank mattmeyerde helping u kick town hall morning townhallforourlives',
#  '',
#  'great day novanation wildcat congrats delawarean donte divincenzo incredible performance',
#  'many gather around seder table evening retell story israelite journey slavery',
#  'era isn equal pay equal work much equality opportun',
#  'proud smyrna h student agree george class peter jr senior class president member youth',
#  'student delaware across country without exception deserve protection law snda spell tha',
#  'thing student worried academic achievement getting bullied discriminated snda letkidslearn',
#  'discrimination bullying harassment belong anywhere let alone school student non discrimination',
#  'student non discrimination act put end discrimination school based sexual orientation gend',
#  'today served ranking member edworkforcedems subcommittee hearing association health plan',
#  'passionate service courageous leadership ensuring people right live love freely',
#  'steve passing heartbreaking rehoboth delaware lgbtq community state whole',
#  'westsidehealth great visit repbrochester discus value community health center provide delawarean thanks rep blun',
#  'thank delaware league local government engaging discussion issue facing city',
#  'proud young men woman leading example showing u support one another challen',
#  'delaware student taking stand gun violence walking saying enough enough',
#  'today pair shoe laid capitol represent child killed due gun violence san',
#  'young people always driving force make positive change proud p dupont student f',
#  'excited p dupont morning speak student recently visited nmaahc',
#  'happy internationalwomensday inspired many woman ve made progress closing gender divide bu',
#  'womenshistorymonth every month let celebrate accomplish empower uplift woman',
#  'de coastline one cherished resource proud testify house natural',
#  'nwlc today aapiequalpay day asian woman pay catch white men made number',
#  'able sleep night knowing look student davidhogg eye',
#  'congress stand child murdered school normalized normal',
#  'teacher student mom dad across country begging u take action re begging u give',
#  're child guy adult need take action play role davidhogg marjory',
#  'urban center rural community every student deserves opportunity learn grow safe',
#  'need right student neighborhood preventing next shooting take anyone life honorwithaction',
#  'shouldn take another mass shooting u deal crisis student dying every day',
#  'classroom neighborhood need create safe space student community grow thrive',
#  'need protect american passing gvro act banning bump stock expanding background check preven',
#  'according everytown american time likely shot killed gun people d',
#  'proud co sponsor gvro act designed prevent people pose threat',
#  'child life worth nra donation ve got honor responsibility',
#  'congrats mike quaranta looking forward working destatechamber help grow economy',
#  'happy chinesenewyear wishing good health good fortune year dog',
#  'public service loan forgiveness income driven repayment built pathway middle class graduate',
#  'housedemocrats repbrochester welcomed fellow delawarean joebiden democratic caucus issue conference united',
#  'thank delaware uaw cap council stopping office talk fair wage protecting worker rig',
#  'fmla important step forward working family year later time national paidleave',
#  'stopped newark natural food co op another supermarketsaturday got hear constituent abou',
#  'officialcbc shuttering office attorney general session saying justice priority thejustic',
#  'dorianwanzer thank supporting health center repbrochester',
#  'drmarkbrainard nursing student excited meet repbrochester morning discus future plan health',
#  'month february pause reflect invaluable contribution african american made throu',
#  'wearing black sotu saying timesup sexual harassment inequality workplace',
#  'cosponsor paycheck fairness act continue fight equalpay equal work behalf',
#  'today mark ninth anniversary lillyledbetter fair pay act signed law important',
#  'today honor six million jew million others killed holocaust',
#  'today stopped deltechpark see exciting new company cutting edge technology innovation',
#  'happy birthday senatorcarper true friend mentor dedicated public servant state better',
#  'today stopped delawaretech terry campus meet drmarkbrainard faculty high school student w',
#  'building prepared workforce start solid foundation polytechpanther student g',
#  'month month budgeting way run business farm government unable support',
#  'congrats eagle earning spot super bowl flyeaglesfly',
#  'information may affected government shutdown please take look federal service',
#  'afitzpayne today repdarrensoto introduced bipartisan ai job act co sponsored aspenfuturework advisory council membe',
#  'administration move reopen atlantic drilling jeopardize economic environmental public healt',
#  'housenewdems owe child future create world lean toward equality progress owe',
#  'officialcbc repbrochester u fight sexual harassment metoo timesup',
#  'let part solution let u commit creating equal inclusive society em',
#  'thank alexis milka stopping office discus daca program provided opportunitie',
#  'today proud join colleague bipartisan heroin task force release legislative agenda',
#  'congress take mantle protecting net neutrality need open internet promote choice fai',
#  'wish family good tidings cheer merry christmas',
#  'proud member congress freshman class may always agree policy ve made',
#  'week joined colleague calling administration stop playing politics cdc',
#  'proud wear delstateuniv color celebrating year excellence hbcus hbcustrong',
#  'tonight delawarean light menorah final time season wish happy hanukkah',
#  'today voted ryan mcconnell tax bill bad deal delaware american people',
#  'delawareestuary thank senatorcarper chriscoons repbrochester supporting funding delawareriver basin restoration',
#  'week joined colleague calling fcc delay net neutrality vote let public',
#  'dad went see star war last night left lightsabers home though wehadablast nospoilers',
#  'calling delawarean open enrollment period end midnight getcovered late',
#  'hour left make sure health insurance visit',
#  'stop re today deadline sign health insurance don wait go',
#  'don wait family may qualify plan cheaper think time running go',
#  'getcovered',
#  'deeply concerned fcc move end important obama era protection net neutrality time co',
#  'repgracemeng pleasure participating round table discussion hosted cbwgcaucus housedemwomen aapolicyforum cong',
#  'clock ticking day left sign health insurance don wait act now goin',
#  'right now offering amendment simplify fafsa make college accesible american background aimhigher',
#  'today spoke behalf repespaillat amendment highered bill give dreamer access stud',
#  'last week joined colleague help committee subchairman repwalberg putting forth legislation help ex',
#  'today lost delaware icon coach tubby raymond undeniable success field legacy liv',
#  'officialcbc cbc libyan ambassador must work together stop despicable slave trade everyone u un eu',
#  'people faith want soul enroll health coverage one week left open enrollment',
#  'never fear first happy delawareday',
#  'paidleave affect every american let move toward standardized policy give worker assurance tha',
#  'wait see tasteofde',
#  'thank ducksunlimited delaware agriculturede secretary scuse stopping office chat',
#  'day left healthcare open enrollment act now going',
#  'last night voted advancing republican tax bill ve heard delawarean need fo',
#  'today met shalomdelaware discus important bond israel well recent',
#  'thanks reaching rachel delawarean interested visiting capitol contact dc office',
#  'world aid day celebrating advance medicine education slowing spread hiv recomm',
#  'world aid day remember lost hiv aid honor memory recommitting endaids wad',
#  'housenewdems thank ambassador martin dahinden swissembassyusa discussing swiss apprenticeship model emba',
#  'go find plan work family',
#  'keep don forget sign health insurance open enrollment end december',
#  're help thanks stopping mobile office hour last night new castle find ho',
#  'today hosting mobile office hour new castle pm pm rte library innovation center',
#  'honor today took part ribbon cutting new runway delaware airpark invest',
#  'great join men woman uniform dover air force base today milcon breakfast state',
#  'support local transgender community tdor giving support need remember',
#  'far least transgender people mostly trans woman color killed must end',
#  'mourn transgender people lost violence transgender day remembrance affirm commitment wo',
#  'repbrochester reidsetzer younginvincible need support simplifying fafsa process encourage student wor',
#  'reidsetzer younginvincible need support simplifying fafsa process encourage student fro',
#  'collegeaccess simple fafsa act move needle today fafsa completion rate percent',
#  'ticas org repbrochester bobbyscott repsusandavis repbera bill provide critical data student selected f',
#  'teamed bobbyscott repbera repsusandavis introduce simple fafsa act aimhigher',
#  'think help working family access federal student aid aimhigher simplefafsa',
#  'know prospective student likely attend college finishing fafsa aimhigher',
#  'today introduced simple fafsa act ensure working family access federal student aid',
#  'destatechamber w usglc chriscoons repbrochester usaidmarkgreen discussion america role world de usglcde',
#  'honesthypocrite talking west africa trip u global leadership make difference repbrochester usglcde americal',
#  'usglc strong statedept important strong military go hand hand repbrochester usglcde americaleads htt',
#  'thank everyone participated telephone town hall tonight gop tax plan',
#  'delkids u representative lisa blount rochester introduces carla benson green distinguished service award recipient repbroche',
#  'honor recognize kindtokids delkids division director carla benson green today commitm',
#  'joined group womenscsa discus work together promote encourage oth',
#  'proud join senatorcarper chriscoons important open enrollment message go',
#  'icinclusion ici tsannicandro cindy thomas david helm went visit repkclark repbrochester robert primus repmikecapuan',
#  'lifelong disability advocate honor deliver closing remark year aucdnews conference',
#  'want hear say sign now join telephone town hall upcoming goptaxbill',
#  'delivery ups',
#  'chesapeakupsers dressed success repbrochester ready start temp job ups package delivery driver',
#  'chesapeakupsers ups christiana package delivery driver eva hall safely pre trip congresswoman lisa rochester blunt befor',
#  'victim loved one impacted today senseless act violence sutherlandsprings thought prayer',
#  'anniehearton repbrochester nice see congresswoman today deartssummit',
#  'wwfh de thank repbrochester voting protect delaware patient medicare benefit yesterday',
#  'health care exchange open business visit now getcovered',
#  'find plan work getcovered open enrollment starting tomorrow visit',
#  'american people deserve truth congress require prevent future tampering election',
#  'artsdelaware thank repbrochester support artsde deartssummit netde',
#  'udelppe repbrochester passionate building strong community taking action now time',
#  'rebeccavallas great convo repbrochester ran congress taking unlockingopportunity peop',
#  'better serve want hear issue mind please feel free take survey',
#  'proud stand lgbtq youth parent school administrator today annual anti bullying gay str',
#  'krobud many thanks repbrochester visiting udceoe wind expert student week',
#  'pdashton thanks bipartisan leadership repbrochester',
#  ...]

# %%
#add the cleaned data to the dataframe
df['clean_tweet']=data_clean

# %%
df.clean_tweet[0]
# Out:
# 'today senate dems vote savetheinternet proud support similar netneutrality legislation house'

# %%
#dataframe with the party_log and clean_tweet
df
# Out:
#             Party         Handle  \
# 0        Democrat  RepDarrenSoto
# 1        Democrat  RepDarrenSoto
# 2        Democrat  RepDarrenSoto
# 3        Democrat  RepDarrenSoto
# 4        Democrat  RepDarrenSoto
# ...           ...            ...
# 86455  Republican    RepTomPrice
# 86456  Republican    RepTomPrice
# 86457  Republican    RepTomPrice
# 86458  Republican    RepTomPrice
# 86459  Republican    RepTomPrice
#
#                                                    Tweet  Party_log  \
# 0      Today, Senate Dems vote to #SaveTheInternet. P...          1
# 1      RT @WinterHavenSun: Winter Haven resident / Al...          1
# 2      RT @NBCLatino: .@RepDarrenSoto noted that Hurr...          1
# 3      RT @NALCABPolicy: Meeting with @RepDarrenSoto ...          1
# 4      RT @Vegalteno: Hurricane season starts on June...          1
# ...                                                  ...        ...
# 86455  Check out my op-ed on need for End Executive O...          0
# 86456  Yesterday, Betty &amp; I had a great time lear...          0
# 86457  We are forever grateful for the service and sa...          0
# 86458  Happy first day of school @CobbSchools! #CobbB...          0
# 86459  #Zika fears realized in Florida. House GOP act...          0
#
#                                              clean_tweet
# 0      today senate dems vote savetheinternet proud s...
# 1      winterhavensun winter haven resident alta vist...
# 2      nbclatino repdarrensoto noted hurricane maria ...
# 3      nalcabpolicy meeting repdarrensoto thanks taki...
# 4      vegalteno hurricane season start june st puert...
# ...                                                  ...
# 86455  check op ed need end executive overreach act w...
# 86456  yesterday betty great time learning forestry i...
# 86457    forever grateful service sacrifice major barney
# 86458  happy first day school cobbschools cobbbacktos...
# 86459  zika fear realized florida house gop acted pre...
#
# [86460 rows x 5 columns]

# %%
import pickle

# %%
#serialize object to file, which can be used later
df.to_pickle("corpus.pkl")
